# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as SGfilter
from IPython.display import clear_output, display
import datetime
import joblib
from tqdm import tqdm
import environment

import gym
import ctfsql
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN
from stable_baselines3 import PPO

# %%
n_simulations = 10
n_episodes_training = 10**6
n_episodes_test = 10**2

# %%
env = gym.make('SQLstruct-v1')

# %%
dqn_model = DQN('MlpPolicy', env, verbose=1, batch_size = 64)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
dqn_model.learn(total_timesteps=10**5)
dqn_model.save('ignore_simulb64_')
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9492     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8325     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 8492     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 85       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9529     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 9241     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 9990     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 180      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10371    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 10489    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.973    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 10508    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 284      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.969    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 10790    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.966    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 10989    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 363      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11246    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 394      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11117    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 434      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.956    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11160    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 458      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11126    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.95     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11095    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.947    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11109    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.945    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11105    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 578      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.943    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11137    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.941    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11168    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 626      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.937    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11226    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 663      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.934    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11118    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 690      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.931    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11302    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.929    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11292    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 746      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.925    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11218    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.922    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11277    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 824      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.918    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11358    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 864      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.915    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11331    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 896      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.911    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11379    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 934      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.908    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11330    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 964      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.905    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11437    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 996      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.902    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11374    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.898    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11383    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.896    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11395    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.892    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11454    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.889    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 11348    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.887    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 11322    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.883    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 11378    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.88     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 11489    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.876    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 11538    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.873    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 11558    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.87     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 11527    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.867    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 11576    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.864    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 11537    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.862    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 11552    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.859    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 11614    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.855    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 11653    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 11623    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.85     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 11614    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.847    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 11648    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.844    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 11634    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.841    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 11642    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.838    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 11608    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.834    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 11616    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.831    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 11673    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.828    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 11624    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.824    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 11729    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.82     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 11686    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.816    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 11716    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.813    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 11727    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.809    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 11755    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.806    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 11798    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.803    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 11784    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.799    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 11810    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.796    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 11785    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.793    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 11783    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.789    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 11792    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.785    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 11816    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.782    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 11854    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.779    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 11876    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.775    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 11928    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.773    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 11894    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.77     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 11929    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.767    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 11906    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.764    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 11912    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.761    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 11871    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.757    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 11868    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.754    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 11888    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.751    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 11925    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.747    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 11944    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.743    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 11940    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.74     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 11958    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.736    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 11976    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2781     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.733    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 11963    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.73     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 11926    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.727    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 11980    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.723    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 11972    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.72     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 11952    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.717    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 11997    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.713    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 12012    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.711    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 11973    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.707    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 12016    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.704    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 11969    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.7      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 12027    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.697    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 11996    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.693    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 12011    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3234     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.69     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 11992    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.686    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 12007    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.684    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 11999    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.68     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 12049    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.678    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 12013    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.674    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 12055    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.671    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 12069    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.667    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 12061    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3501     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.664    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 12050    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.661    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 12077    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.658    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 12062    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.655    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 12048    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.651    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 12061    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.648    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 12057    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.644    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 12069    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.641    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 12091    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.639    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 12065    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.635    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 12077    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.632    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 12060    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.63     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 12047    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.626    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 12059    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.625    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 12037    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.621    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 12037    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.619    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 12022    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.617    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 12036    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.614    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 12024    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.61     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 12047    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.607    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 12023    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.603    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 12035    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.6      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 12060    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.596    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 12071    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.592    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 12048    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.59     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 12053    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.586    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 12083    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.583    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 12077    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.579    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 12087    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.577    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 12064    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.574    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 12086    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.571    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 12069    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.569    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 12068    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.565    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 12068    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.562    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 12083    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.558    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 12093    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.556    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 12092    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.554    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 12063    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.55     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 12073    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.547    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 12093    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.544    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 12084    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.541    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 12089    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.538    |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 12085    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.534    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 12090    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.531    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 12094    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.527    |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 12073    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.524    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 12097    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.521    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 12084    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.518    |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 12077    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.514    |
# ...
# |    n_updates        | 12236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11336    |
# |    fps              | 1205     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 98972    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 12242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11340    |
# |    fps              | 1204     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 98989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 12247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11344    |
# |    fps              | 1204     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 12257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11348    |
# |    fps              | 1204     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99047    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 12261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11352    |
# |    fps              | 1203     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 12271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11356    |
# |    fps              | 1203     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99127    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.69     |
# |    n_updates        | 12281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11360    |
# |    fps              | 1202     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99161    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 12290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11364    |
# |    fps              | 1202     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99195    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 12298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11368    |
# |    fps              | 1202     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71     |
# |    n_updates        | 12304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11372    |
# |    fps              | 1201     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99241    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13     |
# |    n_updates        | 12310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11376    |
# |    fps              | 1201     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0356   |
# |    n_updates        | 12318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11380    |
# |    fps              | 1201     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 12325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11384    |
# |    fps              | 1200     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99330    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 12332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11388    |
# |    fps              | 1200     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99361    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 12340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11392    |
# |    fps              | 1200     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 12345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11396    |
# |    fps              | 1200     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.25     |
# |    n_updates        | 12351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11400    |
# |    fps              | 1199     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 12357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11404    |
# |    fps              | 1199     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99463    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 12365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11408    |
# |    fps              | 1198     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 99503    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 12375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11412    |
# |    fps              | 1198     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99543    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 12385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11416    |
# |    fps              | 1198     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99568    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 12391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11420    |
# |    fps              | 1197     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13     |
# |    n_updates        | 12401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11424    |
# |    fps              | 1197     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99634    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 12408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11428    |
# |    fps              | 1197     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99658    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.15     |
# |    n_updates        | 12414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11432    |
# |    fps              | 1197     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99664    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13     |
# |    n_updates        | 12415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11436    |
# |    fps              | 1196     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99697    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 12424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11440    |
# |    fps              | 1196     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.7      |
# |    n_updates        | 12431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11444    |
# |    fps              | 1196     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99756    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12     |
# |    n_updates        | 12438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11448    |
# |    fps              | 1195     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 12447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11452    |
# |    fps              | 1195     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56     |
# |    n_updates        | 12453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11456    |
# |    fps              | 1195     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99839    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 12459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11460    |
# |    fps              | 1194     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99870    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 12467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11464    |
# |    fps              | 1194     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99903    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 12475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11468    |
# |    fps              | 1194     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99943    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.69     |
# |    n_updates        | 12485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 11472    |
# |    fps              | 1193     |
# |    time_elapsed     | 83       |
# |    total timesteps  | 99974    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71     |
# |    n_updates        | 12493    |
# ----------------------------------

# %%
import evaluate_models as ev

rewards, num_steps = ev.test_episodes(dqn_model, env, num_episodes=1000, max_steps = 100)
len(rewards), len(num_steps)
# Out:
# (1000, 1000)

# %%
plt.plot(num_steps)

# %%
plt.plot(rewards, "o")

# %%
dqn_models = [DQN('MlpPolicy', env, verbose=(i==-1), batch_size = 64) 
              for i in range(n_simulations)]

# %%
for i in tqdm(range(n_simulations)):
    dqn_models[i].learn(total_timesteps=10**6)
    timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
    dqn_models[i].save('ignore_'+ str(i) + '_simulb64_'+timestamp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 10/10 [4:00:34<00:00, 1443.41s/it]

# %%
rewards = []
num_steps = []
for i in tqdm(range(n_simulations)):
    reward, num_step = ev.test_episodes(dqn_models[i], env, num_episodes=1000, max_steps = 50)
    
    num_steps.append(np.array(num_step))
    rewards.append(np.array(reward))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.45s/it]

# %%
for i in range(n_simulations):
    plt.figure()
    plt.plot(num_steps, "o")
    plt.title(str(i))
plt.show()

# %%
plt.boxplot(num_steps.T, notch = True, showmeans = True, meanline = True)
plt.savefig("figures/sim2_b64_test1.png")
